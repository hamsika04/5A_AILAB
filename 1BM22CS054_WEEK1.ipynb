# %% [markdown]
# <a href="https://colab.research.google.com/github/hamsika04/5A_AILAB/blob/main/1BM22CS054_WEEK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random

board = np.array([[-1, -1, -1], [-1, -1, -1], [-1, -1, -1]])

def check_win(b):
    for i in range(3):
        if (b[i, :] == 1).all() or (b[:, i] == 1).all():
            return 1
        if (b[i, :] == 0).all() or (b[:, i] == 0).all():
            return 0
    if (b[0, 0] == b[1, 1] == b[2, 2] == 1) or (b[0, 2] == b[1, 1] == b[2, 0] == 1):
        return 1
    if (b[0, 0] == b[1, 1] == b[2, 2] == 0) or (b[0, 2] == b[1, 1] == b[2, 0] == 0):
        return 0
    return -1

def print_board(b):
    symbols = {1: 'X', 0: 'O', -1: ' '}
    for row in b:
        print(" | ".join(symbols[cell] for cell in row))
        print("---------")

def player_move():
    while True:
        row = int(input("Enter row (0, 1, or 2): "))
        col = int(input("Enter column (0, 1, or 2): "))
        if (row <= 2 and row >= 0) and (col <= 2 and col >= 0):
            if board[row, col] == -1:
                board[row, col] = 1
                break
            else:
                print("Cell is already occupied! Try again.")
        else:
            print("Invalid input, please try again")

def machine_move():
    empty_cells = [(r, c) for r in range(3) for c in range(3) if board[r, c] == -1]
    if empty_cells:
        row, col = random.choice(empty_cells)
        board[row, col] = 0
        print(f"Machine placed O at ({row}, {col})")

def is_full(b):
    return -1 not in b

def play_game():
    print("Welcome to Tic Tac Toe!")
    print_board(board)
    while True:
        print("Player 1's turn (X)")
        player_move()
        print_board(board)
        winner = check_win(board)
        if winner != -1:
            print(f"Player {winner} wins!")
            break
        if is_full(board):
            print("It's a draw!")
            break
        print("Machine's turn (O)")
        machine_move()
        print_board(board)
        winner = check_win(board)
        if winner != -1:
            print(f"Player {winner} wins!")
            break
        if is_full(board):
            print("It's a draw!")
            break

play_game()
# Out:
# Welcome to Tic Tac Toe!
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player 1's turn (X)
# Enter row (0, 1, or 2): 0
# Enter column (0, 1, or 2): 1
#   | X |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Machine's turn (O)
# Machine placed O at (0, 2)
#   | X | O
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player 1's turn (X)
# Enter row (0, 1, or 2): 1
# Enter column (0, 1, or 2): 1
#   | X | O
# ---------
#   | X |
# ---------
#   |   |
# ---------
# Machine's turn (O)
# Machine placed O at (2, 2)
#   | X | O
# ---------
#   | X |
# ---------
#   |   | O
# ---------
# Player 1's turn (X)
# Enter row (0, 1, or 2): 2
# Enter column (0, 1, or 2): 1
#   | X | O
# ---------
#   | X |
# ---------
#   | X | O
# ---------
# Player 1 wins!

# %%
import random

class Room:
    def __init__(self):
        self.state = 'dirty' if random.random() < 0.5 else 'clean'

    def clean(self):
        self.state = 'clean'

class VacuumCleaner:
    def __init__(self, grid_size):
        self.grid_size = grid_size
        self.environment = [[Room() for _ in range(grid_size)] for _ in range(grid_size)]
        self.x, self.y = 0, 0  # Start position

    def display_environment(self):
        print("Current Environment:")
        for row in self.environment:
            print(" | ".join(room.state[0] for room in row))
        print()

    def move(self, direction):
        if direction == 'up' and self.x > 0:
            self.x -= 1
        elif direction == 'down' and self.x < self.grid_size - 1:
            self.x += 1
        elif direction == 'left' and self.y > 0:
            self.y -= 1
        elif direction == 'right' and self.y < self.grid_size - 1:
            self.y += 1

    def clean_current_room(self):
        if self.environment[self.x][self.y].state == 'dirty':
            self.environment[self.x][self.y].clean()
            print(f"Cleaned room at ({self.x}, {self.y})")

    def is_all_clean(self):
        return all(room.state == 'clean' for row in self.environment for room in row)

    def run(self):
        while not self.is_all_clean():
            self.clean_current_room()
            self.display_environment()

            # Random move (up, down, left, right)
            direction = random.choice(['up', 'down', 'left', 'right'])
            self.move(direction)
            print(f"Moved {direction} to ({self.x}, {self.y})")

        print("All rooms are clean! Terminating.")

if __name__ == "__main__":
    grid_size = int(input("Enter the size of the grid (number of rooms per side): "))
    vacuum_cleaner = VacuumCleaner(grid_size)
    vacuum_cleaner.run()
# Out:
# Enter the size of the grid (number of rooms per side): 5
# Cleaned room at (0, 0)
# Current Environment:
# c | c | c | d | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved right to (0, 1)
# Current Environment:
# c | c | c | d | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved right to (0, 2)
# Current Environment:
# c | c | c | d | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 1)
# Current Environment:
# c | c | c | d | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved right to (0, 2)
# Current Environment:
# c | c | c | d | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved up to (0, 2)
# Current Environment:
# c | c | c | d | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved right to (0, 3)
# Cleaned room at (0, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved down to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved up to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved down to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved right to (1, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved up to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved down to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved up to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved down to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved up to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved up to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved right to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved up to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved right to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved right to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved down to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved up to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved up to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved up to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved down to (1, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved right to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved left to (1, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved right to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | d | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved down to (2, 1)
# Cleaned room at (2, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved right to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | d | d
# c | c | d | c | d
# c | c | d | d | d
#
# Moved down to (3, 2)
# Cleaned room at (3, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | d | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | d | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 3)
# Cleaned room at (2, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (2, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved down to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved down to (2, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved down to (3, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (2, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (1, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved down to (2, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 4)
# Cleaned room at (2, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (2, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (1, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (0, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (0, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (0, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved down to (1, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved down to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (0, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (0, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (0, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (0, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (0, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved down to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved down to (2, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (2, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (2, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (2, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved left to (2, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved up to (1, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved down to (2, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved right to (2, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
# c | c | d | d | d
#
# Moved down to (3, 4)
# Cleaned room at (3, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | d | d | d
#
# Moved right to (3, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | d | d | d
#
# Moved left to (3, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | d | d | d
#
# Moved down to (4, 3)
# Cleaned room at (4, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | d | c | d
#
# Moved up to (3, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | d | c | d
#
# Moved down to (4, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | d | c | d
#
# Moved down to (4, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | d | c | d
#
# Moved left to (4, 2)
# Cleaned room at (4, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (3, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (3, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (4, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (4, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (3, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (3, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (3, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (3, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (3, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (4, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (4, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (4, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (3, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (3, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (2, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (3, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (2, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (0, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (1, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (1, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (1, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (2, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (2, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (1, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (1, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (0, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (1, 0)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (0, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (1, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (0, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (0, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved up to (0, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (0, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (1, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (1, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (2, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (2, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (3, 1)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (3, 2)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (3, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (3, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (3, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved left to (3, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved down to (4, 3)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | d
#
# Moved right to (4, 4)
# Cleaned room at (4, 4)
# Current Environment:
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
# c | c | c | c | c
#
# Moved down to (4, 4)
# All rooms are clean! Terminating.
